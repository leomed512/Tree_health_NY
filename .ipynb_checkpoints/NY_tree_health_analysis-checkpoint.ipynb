# %% [markdown]
# # Urban tree health in New Work City
# ##### Data available in https://data.cityofnewyork.us/browse?q=trees&sortBy=relevance&page=1&pageSize=20
# ##### Street tree data from the TreesCount! 2015 Street Tree Census, conducted by volunteers and staff organized by NYC Parks & Recreation and partner organizations.
#
# The dataset shows scientific and common names, health status, DBH, coordinates, silvicultural care works (stewardship), protective fences (guard), among others. Living, dead trees and stumps were recorded.
#
# For the study, only live trees will be used, since it is possible to determine their health status and species.
#
# #### Main objective:
#
# - To determine whether there is a statistically significant relationship between tree species (spc_latin) and tree health status (health).
# - Determine most common species and their health status

# %%
# A virtual environment was created for this project, importing pandas, matplotlib, seaborn and numpy to run this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
from matplotlib.ticker import PercentFormatter
import seaborn as sns
from scipy.stats import chi2_contingency, spearmanr, kruskal
import statsmodels.api as sm
pd.set_option('display.max_columns', None)# To show all columns

# %%
tree_census = pd.read_csv('2015_Street_Tree_Census_-_Tree_Data_20250302.csv')
tree_census.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple     NaN    NaN
# 1                   Quercus palustris          pin oak     NaN    NaN
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
# 4                     Tilia americana  American linden     NaN    NaN
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# 0  NoDamage  TreesCount Staff      NaN         No         No         No
# 1    Damage  TreesCount Staff   Stones        Yes         No         No
# 2    Damage         Volunteer      NaN         No         No         No
# 3    Damage         Volunteer   Stones        Yes         No         No
# 4    Damage         Volunteer   Stones        Yes         No         No
#
#   trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other  \
# 0         No         No         No         No        No         No
# 1         No         No         No         No        No         No
# 2         No         No         No         No        No         No
# 3         No         No         No         No        No         No
# 4         No         No         No         No        No         No
#
#              address  postcode      zip_city  community board  borocode  \
# 0  108-005 70 AVENUE     11375  Forest Hills              406         4
# 1   147-074 7 AVENUE     11357    Whitestone              407         4
# 2  390 MORGAN AVENUE     11211      Brooklyn              301         3
# 3  1027 GRAND STREET     11211      Brooklyn              301         3
# 4       603 6 STREET     11215      Brooklyn              306         3
#
#     borough  cncldist  st_assem  st_senate   nta            nta_name  boro_ct  \
# 0    Queens        29        28         16  QN17        Forest Hills  4073900
# 1    Queens        19        27         11  QN49          Whitestone  4097300
# 2  Brooklyn        34        50         18  BK90   East Williamsburg  3044900
# 3  Brooklyn        34        53         18  BK90   East Williamsburg  3044900
# 4  Brooklyn        39        44         21  BK37  Park Slope-Gowanus  3016500
#
#       state   latitude  longitude         x_sp         y_sp  council district  \
# 0  New York  40.723092 -73.844215  1027431.148  202756.7687              29.0
# 1  New York  40.794111 -73.818679  1034455.701  228644.8374              19.0
# 2  New York  40.717581 -73.936608  1001822.831  200716.8913              34.0
# 3  New York  40.713537 -73.934456  1002420.358  199244.2531              34.0
# 4  New York  40.666778 -73.975979   990913.775  182202.4260              39.0
#
#    census tract        bin           bbl
# 0         739.0  4052307.0  4.022210e+09
# 1         973.0  4101931.0  4.044750e+09
# 2         449.0  3338310.0  3.028870e+09
# 3         449.0  3338342.0  3.029250e+09
# 4         165.0  3025654.0  3.010850e+09

# %% [markdown]
# ## Data Exploration phase

# %% [markdown]
# ### Basic exploration

# %%
tree_census.columns #get all the columns to pick the useful ones
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
# slice only useful columns
tree_subset = tree_census[['tree_id', 'tree_dbh', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
       'borough','latitude', 'longitude']]
tree_subset
# Out:
#         tree_id  tree_dbh status health                           spc_latin  \
# 0        180683         3  Alive   Fair                         Acer rubrum
# 1        200540        21  Alive   Fair                   Quercus palustris
# 2        204026         3  Alive   Good  Gleditsia triacanthos var. inermis
# 3        204337        10  Alive   Good  Gleditsia triacanthos var. inermis
# 4        189565        21  Alive   Good                     Tilia americana
# ...         ...       ...    ...    ...                                 ...
# 683783   155433        25  Alive   Good                   Quercus palustris
# 683784   183795         7  Alive   Good                 Cladrastis kentukea
# 683785   166161        12  Alive   Good                         Acer rubrum
# 683786   184028         9  Alive   Good                         Acer rubrum
# 683787   200607        23  Alive   Fair                         Acer rubrum
#
#                  spc_common steward        borough   latitude  longitude
# 0                 red maple     NaN         Queens  40.723092 -73.844215
# 1                   pin oak     NaN         Queens  40.794111 -73.818679
# 2               honeylocust    1or2       Brooklyn  40.717581 -73.936608
# 3               honeylocust     NaN       Brooklyn  40.713537 -73.934456
# 4           American linden     NaN       Brooklyn  40.666778 -73.975979
# ...                     ...     ...            ...        ...        ...
# 683783              pin oak     NaN       Brooklyn  40.713211 -73.954944
# 683784  Kentucky yellowwood    1or2         Queens  40.715194 -73.856650
# 683785            red maple     NaN  Staten Island  40.620762 -74.136517
# 683786            red maple     NaN          Bronx  40.850828 -73.903115
# 683787            red maple     NaN         Queens  40.732165 -73.787526
#
# [683788 rows x 10 columns]

# %% [markdown]
# #### Managing null/missing values

# %%
tree_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# status             0
# health         31616
# spc_latin      31619
# spc_common     31619
# steward       519438
# borough            0
# latitude           0
# longitude          0
# dtype: int64

# %%
tree_subset[tree_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh status health spc_latin spc_common steward  \
# 37       211205         0  Stump    NaN       NaN        NaN     NaN
# 57       187807         0   Dead    NaN       NaN        NaN     NaN
# 196      208322        10   Dead    NaN       NaN        NaN     NaN
# 209      209058         6   Dead    NaN       NaN        NaN     NaN
# 239      203597         0  Stump    NaN       NaN        NaN     NaN
# ...         ...       ...    ...    ...       ...        ...     ...
# 683693   156162         3   Dead    NaN       NaN        NaN     NaN
# 683695   170888         0  Stump    NaN       NaN        NaN     NaN
# 683697   177922         0  Stump    NaN       NaN        NaN     NaN
# 683698   193791         3   Dead    NaN       NaN        NaN     NaN
# 683699   172660         0  Stump    NaN       NaN        NaN     NaN
#
#               borough   latitude  longitude
# 37             Queens  40.774993 -73.922037
# 57              Bronx  40.871927 -73.882349
# 196          Brooklyn  40.705742 -73.917849
# 209     Staten Island  40.559061 -74.106038
# 239            Queens  40.772483 -73.909073
# ...               ...        ...        ...
# 683693      Manhattan  40.785136 -73.951109
# 683695       Brooklyn  40.647154 -73.955619
# 683697  Staten Island  40.528544 -74.165246
# 683698       Brooklyn  40.590385 -73.972892
# 683699         Queens  40.595866 -73.746149
#
# [31616 rows x 10 columns]

# %%
tree_subset['status'].value_counts()
# Out:
# status
# Alive    652173
# Stump     17654
# Dead      13961
# Name: count, dtype: int64

# %% [markdown]
# ##### Remove dead trees and stumps

# %%
alive = tree_subset[tree_subset['status'] == 'Alive'] #work only with alive trees
alive = alive.drop(columns=['status']) # remove unncesary column
alive.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# health             1
# spc_latin          5
# spc_common         5
# steward       487823
# borough            0
# latitude           0
# longitude          0
# dtype: int64

# %% [markdown]
# #### Basic exploration

# %%
alive.shape
alive.info
alive.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Managing nulls in health - only 1 occurrence
alive[alive['health'].isna()] # might remove this or use a middle term to replace it "Fair"
mask = alive['health'].isna()
alive.loc[mask] = alive.loc[mask].fillna('Fair')

# %%
#Detect NaN in tree identification
alive[alive['spc_latin'].isna()] # Since the species name is relevant it's necessary to remove this
#5 individuals without botanic identification
# Out:
#         tree_id  tree_dbh health spc_latin spc_common steward borough  \
# 356613   562532         4   Good       NaN        NaN    1or2  Queens
# 427541   630814        11   Poor       NaN        NaN     NaN  Queens
# 431417   651014        40   Good       NaN        NaN     NaN  Queens
# 608632    47941         5   Good       NaN        NaN    1or2  Queens
# 656960   150745         3   Good       NaN        NaN    1or2   Bronx
#
#          latitude  longitude
# 356613  40.791332 -73.803610
# 427541  40.771945 -73.750414
# 431417  40.686902 -73.859411
# 608632  40.723484 -73.880296
# 656960  40.894521 -73.858255

# %%
alive = alive.dropna(subset=['spc_latin']) #remove trees without spc_latin
alive.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# health             0
# spc_latin          0
# spc_common         0
# steward       487820
# borough            0
# latitude           0
# longitude          0
# dtype: int64

# %%
# Detect NaN in steward
alive[alive['steward'].isna()]
alive['steward'].value_counts()
# Out:
# steward
# 1or2       143554
# 3or4        19183
# 4orMore      1610
# Fair            1
# Name: count, dtype: int64

# %%
# Replace NaN with None for steward, I assume NaN means there were none
mask = alive['steward'].isna()
alive.loc[mask] = alive.loc[mask].fillna('None')
alive.isna().sum()
alive['steward'] = alive['steward'].replace('Fair', 'None')

# %% [markdown]
# #### Formatting Steward Values (for future analysis)

# %%
# Format steward values
alive['steward_clean'] = alive['steward'].map({
    'None': 0,
    '1or2': 1,
    '3or4': 2,
    '4orMore': 3
})
#print(alive['steward_clean'].value_counts())

# %% [markdown]
# #### Diameter

# %%
alive['tree_dbh'].describe()
# Out:
# count    652168.000000
# mean         11.709478
# std           8.634185
# min           0.000000
# 25%           5.000000
# 50%          10.000000
# 75%          16.000000
# max         425.000000
# Name: tree_dbh, dtype: float64

# %%
bt = alive[['tree_id', 'tree_dbh']].plot(kind='scatter', x= 'tree_id', y='tree_dbh', figsize=(10,5)) #visualize this big trees dist
plt.show()

# %%
# BIG TREES
len(alive[alive['tree_dbh'] > 100])
#full_clean['tree_dbh'].median()
# Out:
# 67

# %%
len(alive[alive['tree_dbh'] < 1]) # 222 data points, therefore it's better to replace those 0 cm dbh trees with the smaller percentile
# Out:
# 222

# %% [markdown]
# ##### Managing Outliers for dbh

# %%
alive.groupby('spc_latin')['tree_dbh'].describe()
#tree_dbh is a potential variable to determine the health of trees 

#Nevertheless, shows 0 dbh trees, this is whether a measure issue or they were registering seedlings smaller than dbh. Nothing in the documentation addresses this issue.
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0   59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0   28.0
# Acer campestre      2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0   64.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0   40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0   30.0
# ...                    ...        ...       ...  ...  ...   ...   ...    ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0   21.0
# Ulmus americana     7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0   65.0
# Ulmus parvifolia    5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0  118.0
# Ulmus pumila        1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0  149.0
# Zelkova serrata    29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0  210.0
#
# [132 rows x 8 columns]

# %%
stats = alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin', 'mean' ,'25%', '75%']] # get the percentiles by species
stats
alive = alive.merge(stats, on='spc_latin', how='left')

# %% [markdown]
# ##### Managing Small trees (dbh== 0.0 inch)

# %%
# Asign 25%th values to 0 dbh trees

## before it's important to explicitly cast the type of 'tree_dbh' from int to float, to match the type of '25%' and avoid future compatibility issues in Pandas
alive['tree_dbh'] = alive['tree_dbh'].astype(float)

condition = alive['tree_dbh'] < alive['25%']
alive.loc[condition, 'tree_dbh'] = alive.loc[condition, '25%']

# %% [markdown]
# ##### Managing big trees  (dbh== 60.0 inch)

# %%
# Asign 75%th value to > 100 dbh inch trees

condition2 = alive['tree_dbh'] >100
alive.loc[condition2, 'tree_dbh'] = alive.loc[condition2, '75%']
len(alive[alive['tree_dbh'] > 100])
alive['tree_dbh'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Format DBH values from inches to centimeters

# %%
# Format dbh units, from inches to cm
alive[['dbh_cm']] = alive[['tree_dbh']]*2.54

# Check conversion
print(alive['dbh_cm'].describe())
# Out:
# count    652168.000000
# mean         31.155410
# std          20.575581
# min           5.080000
# 25%          15.240000
# 50%          25.400000
# 75%          40.640000
# max         254.000000
# Name: dbh_cm, dtype: float64

# %% [markdown]
# ##### Remove unused columns

# %%
#Clean columns
alive= alive.drop(['tree_dbh', 'mean', '25%', '75%'],axis=1)

# %% [markdown]
# #### Visualizing Data

# %%
# Gráfico de barras de frecuencia
plt.figure(figsize=(7, 2))
sns.countplot(y=alive['health'], hue =alive['health'] ,order=alive['health'].value_counts().index) #for categorical variables
plt.title('Health status distribution')
plt.ylabel('Health Status')
plt.xlabel('')
plt.savefig('dbh.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
class_counts = alive['health'].value_counts()
class_proportions = alive['health'].value_counts(normalize=True)
imbalance_ratio = class_counts.max() / class_counts.min()

print(f"Ratio de desbalance: {imbalance_ratio:.2f}")
# Out:
# Ratio de desbalance: 19.72

# %% [markdown]
# ##### Imbalance Ratio: 19.72
# This value indicates that your most frequent class (Good) appears 19.72 times more than your least frequent class (Poor).
# Moderate to severe imbalance: A ratio greater than 10:1 is generally considered a significant imbalance.
#
# ###### Practical interpretation:
# For every tree in the 'Poor' state in your dataset, there are approximately 20 trees in the 'Good' state.
# Implications for modeling: With this level of imbalance, it is expected that unadjusted models will have a strong tendency to predict the majority class, as indeed was observed. This ratio of 19.72:1 clearly indicates the need for balancing techniques.

# %%
# Top 10 common species
top_species = alive['spc_latin'].value_counts().nlargest(10).index

# Sort top 10
filtered_data = alive[alive['spc_latin'].isin(top_species)]

# Crossed Table
health_counts = pd.crosstab(filtered_data['spc_latin'], filtered_data['health'])

# Sort again
health_counts = health_counts.loc[top_species]

health_counts.plot(kind='barh', stacked=True, figsize=(12, 6), colormap='Dark2')

plt.title('Health Distribution for top 10 species')
plt.xlabel('Number of individuals')
plt.ylabel('')
plt.legend(title='Health Status')
plt.savefig('species_health_dist.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.histplot(alive['dbh_cm'], bins=20, kde=True)
plt.xlabel('DBH(cm)')
plt.ylabel('Frequency')
plt.title('DBH Distribution')
plt.savefig('dbh_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Relationship between DBH and Health Status

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1st - Violinplot DBH normal
sns.violinplot(
    ax=axes[0],
    x='health',
    y='dbh_cm',
    data=alive,
    order=['Poor', 'Fair', 'Good'],
    palette='Set2',
    hue='health',
    legend= False
)
axes[0].set_title('DBH Distribution by Health (Original)')
axes[0].set_ylabel('DBH (cm)')

# 2nd - Violinplot log(DBH + 1)
sns.violinplot(
    ax=axes[1],
    x='health',
    y=np.log1p(alive['dbh_cm']),
    data=alive,
    order=['Poor', 'Fair', 'Good'],
    palette='Set2',
    hue='health',
    legend= False
)
axes[1].set_title('Log(DBH + 1) Distribution by Health')
axes[1].set_ylabel('log(DBH + 1)')

plt.tight_layout()
plt.savefig('dbh_distribution_by_health.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Basic Diversity information

# %%
species_counts = alive['spc_latin'].value_counts()

# Create 2 groups
species_below_1000 = species_counts[species_counts < 1000]
species_above_1000 = species_counts[species_counts >= 1000]
with plt.rc_context({'figure.figsize': (10, 6), 'font.size': 10}):
    # Create 2 column chart
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10), sharex=False)
    
    # Species  >=1,000 individuals
    species_above_1000.sort_values().plot(kind='barh', color='darkorange', ax=axes[0])
    axes[0].set_title('Species with more than 1,000 individuals')
    axes[0].set_xlabel('Number of trees')
    axes[0].set_ylabel('Species') 
    axes[0].grid(axis='x', linestyle='--', alpha=0.7)
    
    # Species  < 1,000 individuals
    species_below_1000.sort_values().plot(kind='barh', color='forestgreen', ax=axes[1])
    axes[1].set_title('Species with less than 1,000 individuals')
    axes[1].set_xlabel('Number of trees')
    axes[1].grid(axis='x', linestyle='--', alpha=0.7)
    axes[1].set_ylabel('')
    plt.tight_layout()
    plt.show()

# %%
(alive['spc_latin'].value_counts() > 1000).sum()
# Out:
# np.int64(61)

# %%
(alive['spc_latin'].value_counts() < 200).sum()
# Out:
# np.int64(35)

# %%
(alive['spc_latin'].value_counts() < 50).sum()
# Out:
# np.int64(7)

# %% [markdown]
# ##### Grouping in 'Other species' for Chi square
# It was observed that there is a great inequality between the number of individuals of the different species, many having > 1000 individuals, reaching up to > 8000 individuals, and several species with less than 100 or 50 individuals . This could negatively affect the Chi-Square test, so I had to decide whether to eliminate the latter group or to group them under one name.
#
# I took the latter path, and grouped them under “Other species” so as not to lose their information, as this is a standard procedure in ecological studies, to preserve statistical robustness despite the possible diversity implications that this generalization entails.
#
# ###### Number of species affected = 19 (14,39%)
# ###### Individuals = 1174 (0.171%)

# %%
species_counts = alive['spc_latin'].value_counts()
rare_species = species_counts[species_counts < 100].index
df_clean = alive.copy() 
df_clean['spc_latin'] = df_clean['spc_latin'].replace(rare_species, 'Other species')

# %% [markdown]
# ## Statistical Analysis

# %%
def descriptive_analysis(df):
    """Basic descriptive analysis for health status, number of species and top 10 species"""

    total_trees = len(df_clean)
    print(f'Total number of trees: {total_trees}')
    
    # Health status distribution
    health_counts = df_clean['health'].value_counts()
    print('\nHealth status distribution:')
    print(health_counts)
    print('\nPercentages:')
    print(health_counts / total_trees * 100)

    # Num of species
    n_species = df_clean['spc_common'].nunique()
    print(f"\nNum of species: {n_species}")
    
    # Top 10 common species
    top_species = df['spc_latin'].value_counts().head(10)
    print('\nTop 10 common species:')
    print(top_species)
    
    return 
descriptive_analysis(df_clean)
# Out:
# Total number of trees: 652168
#
# Health status distribution:
# health
# Good    528846
# Fair     96505
# Poor     26817
# Name: count, dtype: int64
#
# Percentages:
# health
# Good    81.090455
# Fair    14.797567
# Poor     4.111977
# Name: count, dtype: float64
#
# Num of species: 132
#
# Top 10 common species:
# spc_latin
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64263
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
# Tilia cordata                         29742
# Prunus                                29279
# Zelkova serrata                       29258
# Ginkgo biloba                         21024
# Styphnolobium japonicum               19338
# Name: count, dtype: int64

# %% [markdown]
# ### Chi-square of independence

# %% [markdown]
# ##### Contingency table

# %%
def contingency_table(df):
    """Creates a contingency table for species and health"""
    # contingency table
    contingency_table = pd.crosstab(df_clean['spc_latin'], df_clean['health'])
    
    # Sort by total number of individuals (from highest to lowest)
    contingency_table['Total'] = contingency_table.sum(axis=1) #create column
    contingency_table_sorted = contingency_table.sort_values('Total', ascending=False)
    
    # Drop Total column for further analysis
    contingency_table = contingency_table_sorted.drop('Total', axis=1)
    
    return contingency_table, contingency_table_sorted
cont_tab, cont_tab_total = contingency_table(df_clean)
cont_tab
# Out:
# health                               Fair   Good  Poor
# spc_latin
# Platanus x acerifolia               11505  73311  2198
# Gleditsia triacanthos var. inermis   8572  54501  1190
# Pyrus calleryana                     8769  48073  2089
# Quercus palustris                    6394  45556  1235
# Acer platanoides                     9162  21248  3779
# ...                                   ...    ...   ...
# Aesculus x carnea                      14     97     5
# Acer nigrum                            18     88     8
# Acer buergerianum                      20     87     3
# Chamaecyparis pisifera                  9     97     2
# Pinus resinosa                         10     95     1
#
# [114 rows x 3 columns]

# %% [markdown]
# ##### Chi-square test

# %%
def chi_sq(contingency_table):
    """Performs a Chi-square of independence"""
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    
    print('\nResults:')
    print(f"Chi2 statistic: {chi2:.2f}")
    print(f"p value: {p:.10f}")
    print(f"Degrees of freedom: {dof}")
    
    alpha = 0.05
    if p < alpha:
        print("Conclusion: There is a significant association between species and health. (p < 0.05)")
    else:
        print("Conclusion: There is insufficient evidence to affirm an association between species and health.")
    
    return {
        'chi2': chi2,
        'p_value': p,
        'dof': dof,
        #'expected': expected
    }
chi_sq(cont_tab)
# Out:
# Results:
# Chi2 statistic: 16732.70
# p value: 0.0000000000
# Degrees of freedom: 226
# Conclusion: There is a significant association between species and health. (p < 0.05)
# {'chi2': np.float64(16732.695844936934),
#  'p_value': np.float64(0.0),
#  'dof': 226}

# %% [markdown]
# ##### Chi-square result's analysis
# Because p-value is so low, almost cero (statistically significant) and Chi2 is very high 16732.70, but the sample size is so large (>680,000), even weak relationships can be statistically significant due to chi-square's sensitivity to sample size.
#
# #### Cramer's V
# Therefore, Cramer's V coefficient could properly complement the analysis by providing a standardized measure of the GLOBAL strength of the association between pairs of variables, which, along with Pearson's standardized residuals, will give a better picture of the relationship between tree species and their health status.

# %%
def cramer_v(contingency_table):
    chi2_stat, p, dof, expected = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum() #sum the df columns (produces a Series) and then sum the values of that Series
    phi2 = chi2_stat/n
    r, k = contingency_table.shape
    cramer_v = np.sqrt(phi2/min(k-1, r-1))
    if (cramer_v <= 0.10):
        msg =  f'Cramer V value is : {cramer_v}, weak or unexisting asociation'
    elif (cramer_v <= 0.20):
        msg =  f'Cramer V value is : {cramer_v}, weak to moderate asociation'
    elif (cramer_v <= 0.40):
        msg =  f'Cramer V value is : {cramer_v}, moderate asociation'
    elif (cramer_v <= 0.60):
        msg =  f'Cramer V value is : {cramer_v}, relatively strong asociation'
    elif (cramer_v <= 0.80):
        msg =  f'Cramer V value is : {cramer_v}, strong asociation'
    elif (cramer_v <= 1):
        msg = f'Cramer V value is : {cramer_v}, very strong asociation'
    return msg

cramer_v(cont_tab)
# Out:
# 'Cramer V value is : 0.11326304101368438, weak to moderate asociation'

# %% [markdown]
# #### Pearson's adjusted residuals (post hoc chi-squared)
#  identifies specific or local associations at the level of individual cells. In such a big sample it is possible that only some specific combinations may have strong associations not easily seen in the prior tests.
# These specific patterns may reveal which species are more likely to present better or worst healdth, hence detect particular vulnerabilities or resistances with implications for urban forest management.
# 1. Prioritize resistant species for future plantings
# 2. Develop special care programs for vulnerable species
# 3. Investigate biological mechanisms of resistance/vulnerability

# %%
def p_residuals(contingency_table):
    """Calculates Pearson's standardized residuals."""
    # Run chi2_contingency to obtain expected values
    _, _, _, expected = chi2_contingency(contingency_table)
    
    # Convert expected to DataFrame with the same indexes and columns
    expected_df = pd.DataFrame(expected, 
                              index=contingency_table.index, 
                              columns=contingency_table.columns)
    
    # Calculate standardized residuals: (observed - expected) / sqrt(expected)
    residuals = (contingency_table - expected_df) / np.sqrt(expected_df)
    
    return residuals
residuals = p_residuals(cont_tab)
residuals
# Out:
# health                                   Fair       Good       Poor
# spc_latin
# Platanus x acerifolia              -12.081854  10.356272 -23.070546
# Gleditsia triacanthos var. inermis  -9.612384  10.468961 -28.255585
# Pyrus calleryana                     0.520925   1.306402  -6.789649
# Quercus palustris                  -16.638800  11.691672 -20.356192
# Acer platanoides                    57.683061 -38.893751  63.293302
# ...                                       ...        ...        ...
# Aesculus x carnea                   -0.763966   0.302625   0.105360
# Acer nigrum                          0.275314  -0.462116   1.529882
# Acer buergerianum                    0.922707  -0.232886  -0.716190
# Chamaecyparis pisifera              -1.746360   1.006840  -1.158295
# Pinus resinosa                      -1.435538   0.975503  -1.608764
#
# [114 rows x 3 columns]

# %% [markdown]
# #### Visualizations for Residuals

# %%
# Inderencial Stastistic Visualizations config
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['font.size'] = 8
plt.rcParams['axes.labelsize'] = 8

# %%
def view_results(contingency_table, residuals):
    """Generate visualizations to interpret results"""
    
    #  Distribution of health status by species (top 15)
    def plot_health_distribution():
        # Transform to %
        prop_table = contingency_table.iloc[:15].copy()  # Top 15 species
        row_sums = prop_table.sum(axis=1)
        prop_table = prop_table.div(row_sums, axis=0) * 100
        
        # Creates figure
        fig, ax = plt.subplots(figsize=(10, 7))
        
        # Stacked bar plot
        prop_table.plot(kind='barh', stacked=True, ax=ax, 
                      color=['#FFC107', '#4CAF50', '#F44336']) 
        
        ax.set_xlabel('Percentage')
        ax.set_ylabel('Species')
        ax.set_title('Distribution (%) of health status top 15 most common species')
        
        ax.legend(title='Health Status',loc=8)
        
        ax.grid(axis='x', alpha=0.3)
        
        # Add percentages to bars
        ax.xaxis.set_major_formatter(PercentFormatter())
        plt.savefig('species_health_residuals.png', dpi=300, bbox_inches='tight')
        plt.tight_layout()

       # return fig
    
    #  Standardized Residuals heat map
    def plot_residuals_heatmap():
        # Select 15 species only
        residuals_top = residuals.iloc[:15]
        
        cmap = sns.diverging_palette(220, 20, as_cmap=True)
        
        fig, ax = plt.subplots(figsize=(10, 7))
        
        # Create heatmap
        sns.heatmap(residuals_top, cmap=cmap, center=0, 
                  annot=True, fmt=".2f", linewidths=.5, ax=ax,
                  cbar_kws={'label': 'Standardized Residuals'})
        
        ax.set_title('Standardized residuals by species and health status (Top 15)')
        ax.set_xlabel('Health Status')
        ax.set_ylabel('Species')
        
        plt.tight_layout()
        plt.savefig('species_map_by_health.png', dpi=300, bbox_inches='tight')
        plt.show()
        #return fig
    
    # Mosaic chart for the top 5 species
    from statsmodels.graphics.mosaicplot import mosaic

    
    # run visualizations
    fig1 = plot_health_distribution()
    fig2 = plot_residuals_heatmap()


view_results(cont_tab, residuals)

# %% [markdown]
# #### General patterns:
#
# ##### Species with better than average health (positive residuals in “Good” and negative in “Poor”):
#
# 1. Platanus x acerifolia
# 2. Gleditsia triacanthos var. inermis
# 3. Quercus palustris
# 4. Zelkova serrata
#
#
# ##### Species with worse health than average (negative residuals in “Good” and positive in “Poor”):
#
# 1. Acer platanoides (the most extreme case).
# 2. Tilia cordata (although not in “Fair”)
#
#
# ##### Species with mixed or less marked patterns:
#
# 1. Prunus
# 2. Ginkgo biloba
# 3. Tilia americana
#
#
#
# ##### Remarks for forest management:
# 1. Acer platanoides shows very significant health problems, which could indicate:
#
# High susceptibility to pests or diseases.
# Poor adaptation to urban conditions of NY
# Possible need to reconsider its use in new plantings.
#
#
# 2. Platanus x acerifolia, Gleditsia triacanthos and Quercus palustris could be preferred candidates for future plantings due to their better health status.
# It would be useful to investigate the specific characteristics that make some species perform better, such as:
#
# Tolerance to contamination
# Resistance to common diseases
# Adaptation to urban conditions

# %% [markdown]
# #### Visualize with Qgis

# %%
# Geo info Latitude and Longitude uses the coordinate system GCS_WGS_1984. 
alive.to_csv('alive.csv',index=False)

# %% [markdown]
# ### Identify Significant Associations

# %% [markdown]
# #### Visualize most resistent species and less resistent species

# %%
# 1. Create a health metric by species using standardized residues 

# DF with residuals, species and health status
species_health = pd.DataFrame(residuals.stack()).reset_index()
species_health.columns = ['spc_latin', 'health', 'residual']

# Calculate ponderated health 
def health_score(group):
    score = 0
    # Weights for each category
    weights = {'Good': 1.0, 'Fair': 0.0, 'Poor': -1.0}
    
    for _, row in group.iterrows():
        # Multiply residual by corresponding weight
        score += row['residual'] * weights[row['health']]
    
    return score

# Group by species and calculate score 

spc_scores = species_health.groupby('spc_latin').apply(health_score, include_groups=False)
spc_scores = spc_scores.reset_index()
spc_scores.columns = ['spc_latin', 'score_health']

# 2. Identify 10 species with best health and worst health
best_spc = spc_scores.sort_values('score_health', ascending=False).head(10)
poor_spc = spc_scores.sort_values('score_health', ascending=True).head(10)


# Merge two types into a single DF 
top_especies = pd.concat([
    best_spc.assign(category="Better Health"),
    poor_spc.assign(category="Poor Health")
])

plt.figure(figsize=(10, 5))
ax = sns.barplot(x='score_health', y='spc_latin', hue='category', 
                data=top_especies, palette={'Better Health': 'green', 'Poor Health': 'red'})
plt.title('Species health comparision', fontsize=16)
plt.xlabel('Health score (from residuals)', fontsize=12)
plt.ylabel('Species', fontsize=12)
plt.axvline(x=0, color='black', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.legend(title="", loc = 8 )
plt.savefig('species_health_comparision.png', dpi=300, bbox_inches='tight')
plt.show()
